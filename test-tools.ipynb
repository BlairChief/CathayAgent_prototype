# %%
from dotenv import load_dotenv
from phi.agent import Agent
from tools import FirstMillionCalculator, Searxng

load_dotenv()
# Out:
# True

# %%
agent = Agent(
    tools=[
        FirstMillionCalculator(),
    ],
    show_tool_calls=True,
    markdown=True,
    debug_mode=True,
)

agent.print_response(
    "Given my annual return rate is 2 percent, how long would it take for me to save USD 1,000,000 if my monthly saving is USD 5000? ",
    markdown=True
)

# %%
agent = Agent(
    tools=[
        Searxng(),
    ],
    show_tool_calls=True,
    markdown=True,
    debug_mode=True,
)

agent.print_response(
    "Could you go on the internet and find what publications that Richard Feynman has published?",
    markdown=True
)
# Out:
# DEBUG    Function: search registered with searxng
# DEBUG    *********** Agent ID: 41a3890d-464b-46f8-9e3d-aa37d823aaee ***********
# DEBUG    *********** Session ID: 7526001c-cd4a-4f1a-9ef2-524a32cec55c ***********
# DEBUG    Debug logs enabled
# DEBUG    *********** Agent Run Start: 94dbed68-5bda-4e70-904c-74e6a6628a2c ***********
# DEBUG    Function search from searxng added to model.
# DEBUG    ---------- OpenAI Response Start ----------
# DEBUG    ============== system ==============
# DEBUG    ## Instructions
#          Use markdown to format your answers.
# DEBUG    ============== user ==============
# DEBUG    Could you go on the internet and find what publications that Richard Feynman has published?
# /home/johnbjohn/Documents/repositories/Phidata_prototype/.venv/lib/python3.12/site-packages/rich/live.py:231:
# ...
#   warnings.warn('install "ipywidgets" for Jupyter support')
# DEBUG    ============== assistant ==============
# DEBUG    Tool Calls: [
#            {
# ...
